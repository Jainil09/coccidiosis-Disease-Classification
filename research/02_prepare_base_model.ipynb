# %%
import os

# %%
# %pwd
# Out:
# 'd:\\Jai\\coccidiosis-Disease-Classification\\research'

# %%
os.chdir("../")

# %%
# %pwd
# Out:
# 'd:\\Jai\\coccidiosis-Disease-Classification'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class PrepareBaseModelConfig:
    root_dir: Path
    base_model_path: Path
    updated_base_model_path: Path
    params_image_size: list
    params_learning_rate: float
    params_include_top: bool
    params_weights: str
    params_classes: int

# %%
from src.cnnClassifier.constants import *
from src.cnnClassifier.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self, 
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAMS_FILE_PATH):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        create_directories([self.config.artifacts_root])


    def get_prepare_base_model_config(self) -> PrepareBaseModelConfig:
        config = self.config.prepare_base_model
        
        create_directories([config.root_dir])

        prepare_base_model_config = PrepareBaseModelConfig(
            root_dir=Path(config.root_dir),
            base_model_path=Path(config.base_model_path),
            updated_base_model_path=Path(config.updated_base_model_path),
            params_image_size=self.params.IMAGE_SIZE,
            params_learning_rate=self.params.LEARNING_RATE,
            params_include_top=self.params.INCLUDE_TOP,
            params_weights=self.params.WEIGHTS,
            params_classes=self.params.CLASSES
        )

        return prepare_base_model_config

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.12.0-cp38-cp38-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.12.0
#   Using cached tensorflow_intel-2.12.0-cp38-cp38-win_amd64.whl (272.8 MB)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.54.2)
# Collecting tensorboard<2.13,>=2.12
#   Using cached tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.23.2)
# Requirement already satisfied: six>=1.12.0 in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Collecting jax>=0.3.15
#   Using cached jax-0.4.11-py3-none-any.whl
# Requirement already satisfied: packaging in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.1)
# Requirement already satisfied: keras<2.13,>=2.12.0 in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.31.0)
# Requirement already satisfied: google-pasta>=0.1.1 in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.12.0)
# Requirement already satisfied: h5py>=2.9.0 in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.6.3)
# Requirement already satisfied: numpy<1.24,>=1.22 in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.23.5)
# Requirement already satisfied: libclang>=13.0.0 in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (16.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (2.3.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (3.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (0.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.5.26)
# Requirement already satisfied: absl-py>=1.0.0 in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.4.0)
# Requirement already satisfied: setuptools in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (67.8.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\chicken\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.38.4)
# Requirement already satisfied: ml-dtypes>=0.1.0 in d:\chicken\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in d:\chicken\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (1.10.1)
# Requirement already satisfied: importlib-metadata>=4.6 in d:\chicken\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (6.6.0)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.19.1-py2.py3-none-any.whl (181 kB)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\chicken\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.31.0)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\chicken\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.3.4)
# Requirement already satisfied: markdown>=2.6.8 in d:\chicken\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in d:\chicken\lib\site-packages (from tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.7.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\chicken\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.3.0)
# Requirement already satisfied: urllib3<2.0 in d:\chicken\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.26.16)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\chicken\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (5.3.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\chicken\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in d:\chicken\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in d:\chicken\lib\site-packages (from importlib-metadata>=4.6->jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (3.15.0)
# Requirement already satisfied: idna<4,>=2.5 in d:\chicken\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\chicken\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\chicken\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\chicken\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in d:\chicken\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in d:\chicken\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow-intel==2.12.0->tensorflow) (3.2.2)
# Installing collected packages: jax, google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
# Successfully installed google-auth-2.19.1 google-auth-oauthlib-1.0.0 jax-0.4.11 tensorboard-2.12.3 tensorflow-2.12.0 tensorflow-intel-2.12.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import urllib.request as request
from zipfile import ZipFile
import tensorflow as tf
# Out:
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'd:\\chicken\\Lib\\site-packages\\tensorflow\\lite\\experimental\\microfrontend\\python\\ops\\_audio_microfrontend_op.so'
# Consider using the `--user` option or check the permissions.
# Collecting tensorflow
#   Downloading tensorflow-2.12.0-cp38-cp38-win_amd64.whl (1.9 kB)
# Collecting tensorflow-intel==2.12.0
#   Downloading tensorflow_intel-2.12.0-cp38-cp38-win_amd64.whl (272.8 MB)
#      -------------------------------------- 272.8/272.8 MB 4.2 MB/s eta 0:00:00
# Collecting tensorboard<2.13,>=2.12
#   Using cached tensorboard-2.12.3-py3-none-any.whl (5.6 MB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting flatbuffers>=2.0
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Collecting wrapt<1.15,>=1.11.0
#   Downloading wrapt-1.14.1-cp38-cp38-win_amd64.whl (35 kB)
# Collecting jax>=0.3.15
#   Using cached jax-0.4.11.tar.gz (1.3 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting h5py>=2.9.0
#   Downloading h5py-3.8.0-cp38-cp38-win_amd64.whl (2.7 MB)
#      ---------------------------------------- 2.7/2.7 MB 9.4 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.12.0 in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (1.16.0)
# Collecting libclang>=13.0.0
#   Using cached libclang-16.0.0-py2.py3-none-win_amd64.whl (24.4 MB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp38-cp38-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (67.8.0)
# Requirement already satisfied: packaging in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (23.1)
# Collecting numpy<1.24,>=1.22
#   Downloading numpy-1.23.5-cp38-cp38-win_amd64.whl (14.7 MB)
#      ---------------------------------------- 14.7/14.7 MB 7.3 MB/s eta 0:00:00
# Collecting absl-py>=1.0.0
#   Using cached absl_py-1.4.0-py3-none-any.whl (126 kB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting tensorflow-estimator<2.13,>=2.12.0
#   Using cached tensorflow_estimator-2.12.0-py2.py3-none-any.whl (440 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.54.2-cp38-cp38-win_amd64.whl (4.1 MB)
#      ---------------------------------------- 4.1/4.1 MB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\chicken\lib\site-packages (from tensorflow-intel==2.12.0->tensorflow) (4.6.3)
# Collecting keras<2.13,>=2.12.0
#   Using cached keras-2.12.0-py2.py3-none-any.whl (1.7 MB)
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Downloading protobuf-4.23.2-cp38-cp38-win_amd64.whl (422 kB)
#      -------------------------------------- 422.5/422.5 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\chicken\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.12.0->tensorflow) (0.38.4)
# Collecting ml-dtypes>=0.1.0
#   Downloading ml_dtypes-0.2.0-cp38-cp38-win_amd64.whl (938 kB)
#      -------------------------------------- 938.6/938.6 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=4.6 in d:\chicken\lib\site-packages (from jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (6.6.0)
# Collecting scipy>=1.7
#   Downloading scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
#      ---------------------------------------- 42.2/42.2 MB 5.2 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.0-py3-none-any.whl (2.4 kB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.19.1-py2.py3-none-any.whl (181 kB)
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.4.3-py3-none-any.whl (93 kB)
# Collecting werkzeug>=1.0.1
#   Using cached Werkzeug-2.3.4-py3-none-any.whl (242 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ---------------------------------------- 62.6/62.6 kB ? eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting urllib3<2.0
#   Downloading urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
#      -------------------------------------- 143.1/143.1 kB 4.3 MB/s eta 0:00:00
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: zipp>=0.5 in d:\chicken\lib\site-packages (from importlib-metadata>=4.6->jax>=0.3.15->tensorflow-intel==2.12.0->tensorflow) (3.15.0)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2023.5.7-py3-none-any.whl (156 kB)
#      -------------------------------------- 157.0/157.0 kB 2.3 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.1.0-cp38-cp38-win_amd64.whl (96 kB)
#      ---------------------------------------- 96.4/96.4 kB 2.8 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-2.1.3-cp38-cp38-win_amd64.whl (17 kB)
# Collecting pyasn1<0.6.0,>=0.4.6
#   Using cached pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Building wheels for collected packages: jax
#   Building wheel for jax (pyproject.toml): started
#   Building wheel for jax (pyproject.toml): finished with status 'done'
#   Created wheel for jax: filename=jax-0.4.11-py3-none-any.whl size=1487992 sha256=6046093de0c2e679b156fd6f730fd7971721bdda4f551d8ec44047f7878a32b2
#   Stored in directory: c:\users\pbp18\appdata\local\pip\cache\wheels\65\e8\48\e882a3b1894ac6faa056112773675b7fee52390b219207334f
# Successfully built jax
# Installing collected packages: libclang, flatbuffers, wrapt, urllib3, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, pyasn1, protobuf, oauthlib, numpy, MarkupSafe, keras, idna, grpcio, google-pasta, gast, charset-normalizer, certifi, cachetools, astunparse, absl-py, werkzeug, scipy, rsa, requests, pyasn1-modules, opt-einsum, ml-dtypes, markdown, h5py, requests-oauthlib, jax, google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow

# %%
class PrepareBaseModel:
    def __init__(self, config: PrepareBaseModelConfig):
        self.config = config


    
    def get_base_model(self):
        self.model = tf.keras.applications.vgg16.VGG16(
            input_shape=self.config.params_image_size,
            weights=self.config.params_weights,
            include_top=self.config.params_include_top
        )

        self.save_model(path=self.config.base_model_path, model=self.model)


    
    @staticmethod
    def _prepare_full_model(model, classes, freeze_all, freeze_till, learning_rate):
        if freeze_all:
            for layer in model.layers:
                model.trainable = False
        elif (freeze_till is not None) and (freeze_till > 0):
            for layer in model.layers[:-freeze_till]:
                model.trainable = False

        flatten_in = tf.keras.layers.Flatten()(model.output)
        prediction = tf.keras.layers.Dense(
            units=classes,
            activation="softmax"
        )(flatten_in)

        full_model = tf.keras.models.Model(
            inputs=model.input,
            outputs=prediction
        )

        full_model.compile(
            optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate),
            loss=tf.keras.losses.CategoricalCrossentropy(),
            metrics=["accuracy"]
        )

        full_model.summary()
        return full_model
    

    def update_base_model(self):
        self.full_model = self._prepare_full_model(
            model=self.model,
            classes=self.config.params_classes,
            freeze_all=True,
            freeze_till=None,
            learning_rate=self.config.params_learning_rate
        )

        self.save_model(path=self.config.updated_base_model_path, model=self.full_model)

    
    @staticmethod
    def save_model(path: Path, model: tf.keras.Model):
        model.save(path)

# %%
try:
    config = ConfigurationManager()
    prepare_base_model_config = config.get_prepare_base_model_config()
    prepare_base_model = PrepareBaseModel(config=prepare_base_model_config)
    prepare_base_model.get_base_model()
    prepare_base_model.update_base_model()
except Exception as e:
    raise e
# Out:
# [2023-06-06 21:38:10,940: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2023-06-06 21:38:11,280: INFO: common: yaml file: params.yaml loaded successfully]
# [2023-06-06 21:38:11,322: INFO: common: created directory at: artifacts]
# [2023-06-06 21:38:11,332: INFO: common: created directory at: artifacts/prepare_base_model]
# [2023-06-06 21:38:15,263: WARNING: saving_utils: Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.]
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 2)                 50178
#
# =================================================================
# Total params: 14,764,866
# Trainable params: 50,178
# Non-trainable params: 14,714,688
# _________________________________________________________________
